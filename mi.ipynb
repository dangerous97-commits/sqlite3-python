# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
conn = sqlite3.connect('sales.db')
c = conn.cursor()

df = pd.read_sql_query('select * from sales_table',conn)
# print(df)

# Step 1: Connect to database
# Step 2: Run basic SQL
query = """
SELECT product_name AS product,
       SUM(quantity) AS total_qty,
       SUM(quantity * product_price) AS revenue
FROM sales_table
GROUP BY product_name
"""
df = pd.read_sql_query(query, conn)

# Step 3: Close connection
conn.close()

# Step 4: Print results
print(df)

# Step 5: Plot simple bar chart
df.plot(kind='bar', x='product', y='revenue', color='skyblue', legend=False)
plt.xlabel("Product")
plt.ylabel("Revenue (₹)")
plt.title("Revenue per Product")
plt.xticks(rotation=45)
plt.tight_layout()

# Step 6: Save chart
plt.savefig("sales_chart.png", dpi=300)

# Step 7: Show chart
plt.show()
# Out:
#       product  total_qty  revenue
# 0      Camera         59  1462113
# 1  Headphones         86  1218712
# 2    Keyboard        102  2770470
# 3      Laptop         60  1498407
# 4      Mobile        121  3934542
# 5     Monitor         86  2332680
# 6       Mouse         90  1466175
# 7     Printer         82  1943459
# 8  Smartwatch         80  2356614
# 9      Tablet        140  3191310
